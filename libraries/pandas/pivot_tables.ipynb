# %%
# Importing the Libraries

import pandas as pd
import numpy as np

# %%
# Reading the dataset from the Github Repository

df = pd.read_csv("/usr/local/notebooks/datasets/users_data.csv")

# %% [markdown]
# <h3 style="color:red;">Dataset Description</h3>
# <br/>
# <b style="color:blue;">Below Dataset is about users living in different Countries</b>

# %%
# Printing the First 5 rows

df.head()
# Out:
#   first_name   last_name                       email  gender     salary  \
# 0       Jeni    Radborne  jradborne0@statcounter.com  Female  $41499.57
# 1       Addy     Vockins     avockins1@goodreads.com  Female  $11273.94
# 2     Stefan  Kitteridge     skitteridge2@oakley.com    Male  $18321.47
# 3      Hyatt     Dungate            hdungate3@w3.org    Male  $93141.07
# 4       Anni    Folomkin        afolomkin4@wiley.com  Female  $98292.30
#
#    weight  age  height      Country
# 0      96   23       5  Philippines
# 1      94   46       7        China
# 2      87   41       6      Nigeria
# 3      50   33       5       Poland
# 4      95   29       6       Mexico

# %% [markdown]
# <h3 style="color:red;">Task</h3>
# <br/>
# <b style="color:blue;">Below Pivot Table gives us the mean of weights in both Males and Females
# across all the countries. We have the countries as the columns and gender as the index.
# While the inner values of the Table are the sum of weights </b>

# %%
# Constructing the Pivot Table

table = pd.pivot_table(df, values='weight', index=['gender'], columns=['Country'], aggfunc=np.mean, fill_value=0)

# %%
# Displaying the Pivot Table

table
# Out:
# Country  Afghanistan  Aland Islands    Albania  Angola  Argentina    Armenia  \
# gender
# Female            88              0  73.333333       0  69.000000  76.333333
# Male              72             57  86.500000      77  76.444444  64.000000
#
# Country  Australia  Austria  Azerbaijan  Bahrain  ...   Thailand  Uganda  \
# gender                                            ...
# Female           0        0          76        0  ...  72.857143    71.5
# Male            67       50          87       58  ...  75.000000     0.0
#
# Country    Ukraine  United Kingdom  United States  Uruguay  Venezuela  \
# gender
# Female   66.333333               0      72.470588       71         98
# Male     68.875000              56      77.071429       52         80
#
# Country  Vietnam  Yemen  Zimbabwe
# gender
# Female        68   94.0        95
# Male          82   76.5        83
#
# [2 rows x 121 columns]
