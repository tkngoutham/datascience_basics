# %%
import scrapy


class QuestionsSpider(scrapy.Spider):
    name = "questions"
    start_urls = [
        'https://datascience.stackexchange.com/'
    ]

    def parse(self, response):
        counter = 0

        for question in response.css('div.s-post-summary'):

            counter = counter + 1

            summary = question.css("div.s-post-summary--content h3 a.s-link::text").get()
            votes = question.css("div.s-post-summary--stats div.s-post-summary--stats-item__emphasized span.s-post-summary--stats-item-number::text").get()
            number_of_answers = question.css("div.s-post-summary--stats div.has-answers span.s-post-summary--stats-item-number::text").get()
            views = question.css("div.s-post-summary--stats div:last-child span.s-post-summary--stats-item-number::text").get()
            
            print(dict(summary=summary, votes=votes, number_of_answers=number_of_answers, views=views))

            if counter == 10:
                break

from scrapy.crawler import CrawlerProcess
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})
process.crawl(QuestionsSpider)
process.start() # the script will block here until the crawling is finished
# Out:
# 2024-10-07 14:06:31 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2024-10-07 14:06:31 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.12 (main, Apr  5 2022, 01:53:17) - [Clang 12.0.0 ], pyOpenSSL 21.0.0 (OpenSSL 1.1.1n  15 Mar 2022), cryptography 3.4.8, Platform macOS-10.16-x86_64-i386-64bit
# 2024-10-07 14:06:31 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2024-10-07 14:06:31 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-10-07 14:06:31 [scrapy.extensions.telnet] INFO: Telnet Password: 45753f2991fa2810
# 2024-10-07 14:06:31 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-10-07 14:06:32 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-10-07 14:06:32 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-10-07 14:06:32 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-10-07 14:06:32 [scrapy.core.engine] INFO: Spider opened
# 2024-10-07 14:06:32 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-10-07 14:06:32 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-10-07 14:06:32 [filelock] DEBUG: Attempting to acquire lock 140280222016032 on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-10-07 14:06:32 [filelock] DEBUG: Lock 140280222016032 acquired on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-10-07 14:06:32 [filelock] DEBUG: Attempting to acquire lock 140280354348144 on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-10-07 14:06:32 [filelock] DEBUG: Lock 140280354348144 acquired on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-10-07 14:06:32 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2024-10-07 14:06:32 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/11" 200 84182
# 2024-10-07 14:06:32 [filelock] DEBUG: Attempting to release lock 140280354348144 on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-10-07 14:06:32 [filelock] DEBUG: Lock 140280354348144 released on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2024-10-07 14:06:32 [filelock] DEBUG: Attempting to release lock 140280222016032 on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-10-07 14:06:32 [filelock] DEBUG: Lock 140280222016032 released on /Users/kittu/.cache/python-tldextract/3.9.12.final__anaconda3__1ba1ae__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2024-10-07 14:06:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://datascience.stackexchange.com/> (referer: None)
# 2024-10-07 14:06:33 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-10-07 14:06:33 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 249,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 34881,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.73014,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 10, 7, 8, 36, 33, 38645),
#  'httpcompression/response_bytes': 168609,
#  'httpcompression/response_count': 1,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 10,
#  'memusage/max': 100626432,
#  'memusage/startup': 100626432,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2024, 10, 7, 8, 36, 32, 308505)}
# 2024-10-07 14:06:33 [scrapy.core.engine] INFO: Spider closed (finished)
# {'summary': 'ML regression for skewed data', 'votes': '0', 'number_of_answers': '3', 'views': '5k'}
# {'summary': "CNN can't predict images outside the dataset", 'votes': '1', 'number_of_answers': '1', 'views': '521'}
# {'summary': "How to use Variational Autoencoder's μ and σ with user-generated z?", 'votes': '1', 'number_of_answers': '1', 'views': '1k'}
# {'summary': 'Deep fully connected NN with vanishing gradients', 'votes': '0', 'number_of_answers': '1', 'views': '166'}
# {'summary': 'Similarity Matching Algorithm', 'votes': '0', 'number_of_answers': '1', 'views': '233'}
# {'summary': 'causal inference vs sensitivity analysis to create acurate ML predictions?', 'votes': '1', 'number_of_answers': '1', 'views': '188'}
# {'summary': 'Sampling methods for Text datasets (NLP)', 'votes': '1', 'number_of_answers': '1', 'views': '706'}
# {'summary': 'Train, test split of unbalanced dataset classification', 'votes': '22', 'number_of_answers': '4', 'views': '80k'}
# {'summary': 'How to use SMOTENC inside the Pipeline?', 'votes': '3', 'number_of_answers': '1', 'views': '1k'}
# {'summary': 'Solving multi-class imbalance classification using smote and OSS', 'votes': '2', 'number_of_answers': '2', 'views': '3k'}
