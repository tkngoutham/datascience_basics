# %% [markdown]
# # Line Plot
# <hr>
#
# # Dataset Description
# <hr>
#
# <p style="color:blue; font-size:18px;"> This dataset is about the montly sales of a shampoo over a period of three years. The units are the sales counts in each month. This Dataset has been taken from <a href="https://www.kaggle.com/pafrantz/sales-of-shampoo"> Kaggle </a>
#
#
#
# Line plots are most commonly used to see the trend in the variable chronologically over time. They are mostly used in Time Series Analysis. It is most likely the Scatter plot except the values are sorted chronologically on the x-axis and are joined by line segments.
#
# We will use the Shampoo Sales Dataset to make a Line plot.
# </p>

# %%
# Importing the libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the Dataset
dataset  = pd.read_csv("/usr/local/notebooks/datasets/sales-of-shampoo-over-a-three-ye.csv")

# %%
dataset.head()
# Out:
#   Month  Sales of shampoo over a three year period
# 0  1-01                                      266.0
# 1  1-02                                      145.9
# 2  1-03                                      183.1
# 3  1-04                                      119.3
# 4  1-05                                      180.3

# %%
dataset.drop(dataset.tail(1).index,inplace=True) # drop last row

# %%
dataset.shape
# Out:
# (36, 2)

# %%
dataset.columns
# Out:
# Index(['Month', 'Sales of shampoo over a three year period'], dtype='object')

# %%
dataset.dtypes
# Out:
# Month                                         object
# Sales of shampoo over a three year period    float64
# dtype: object

# %%
# Renaming the Sales Column
dataset.rename(columns ={"Sales of shampoo over a three year period" : "Number of Sales"}, inplace=True)

# %%
dataset.head()
# Out:
#   Month  Number of Sales
# 0  1-01            266.0
# 1  1-02            145.9
# 2  1-03            183.1
# 3  1-04            119.3
# 4  1-05            180.3

# %% [markdown]
# # Columns Description
# <hr/>
# <div style="font-size:18px">
# <p style="color:blue;"> Columns in the Dataset are : </p>
#
# <ul>
#     <li> Month : This is the month in which the sale happened. </li>
#     <br>
#     <li> Sales of Shampoo over a three year period : Number of Sales Happened </li>
#
# </ul>
#
# </div>

# %% [markdown]
# # Task
# <hr/>
# <p style="font-size:18px; color:purple"> We will be looking at the Lineplot of the Sales Happened over Time. </p>

# %%
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize = (24,10))    
line_plot = sns.lineplot(x="Month", y="Number of Sales", data=dataset , ax=ax)
fig = line_plot.set_title("Sales Happened Over Time")

# %% [markdown]
# # Conclusion
#
# <hr/>
#
# <div style="font-size:18px">
#
# <ul>
#     <li> Above Line Plot shows us the Sales Happened Over Time.</li>
#     <br>
#     <li> We can see that there is an upward trend in the Sales. </li>
#     <br>
#     <li> There is also a seasonal component in the Sales.</li>
#
# </ul>
